# %%
# %run difference.py

# %run uniform.py
# Out:
# Generating sorted array of 1000000 random numbers between 0 and 10000000...
#
# Done.
#
#
# Generating array of the difference of each number to their predecessor...
#
# Done.
#
#
# Plotting generated data...
# Done.
#
#
# Generating array of 1000000 random numbers between 0 and 1...
#
# Done.
#
#
# Applying formula to generated numbers ...
# Done.
#
#
# Examining generated data...
#
# Mean value of the generated data: 6.666194939095424
#
# Mu times mean: 0.9999292408643135
#
# Variance of the generated data: 44.471898205655286
#
# Mu times mu times variance: 1.000617709627244
#
# Done.
#
#
# Plotting generated data...
# Done.
